# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /home/saicharan/.local/lib/python3.8/site-packages (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (45.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (20.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.34.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.32.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.1.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/saicharan/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.25.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow keras matplotlib
# Out:
# Requirement already satisfied: tensorflow in /home/saicharan/.local/lib/python3.8/site-packages (2.9.1)
# Requirement already satisfied: keras in /home/saicharan/.local/lib/python3.8/site-packages (2.9.0)
# Requirement already satisfied: matplotlib in /home/saicharan/.local/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (45.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (20.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (7.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: cycler>=0.10 in /home/saicharan/.local/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.34.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.32.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/saicharan/.local/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.1.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/saicharan/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.20.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2019.11.28)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/saicharan/.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.25.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/saicharan/.local/lib/python3.8/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Disable GPU

from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import scipy
# Out:
# 2024-10-15 13:08:27.141611: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-10-15 13:08:27.141660: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#Cell 2: Data Augmentation and loading (modify file paths accordingly)
train_datagen = ImageDataGenerator(
    rescale=1./255,           
    shear_range=0.2,          
    zoom_range=0.2,           
    horizontal_flip=True,      
    rotation_range=20,        
    width_shift_range=0.2,    
    height_shift_range=0.2,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    'training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)

test_set = test_datagen.flow_from_directory(
    'test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 4009 images belonging to 2 classes.
# Found 978 images belonging to 2 classes.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Disable GPU

from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import scipy  # Ensure SciPy is imported

# ... rest of your code ...

cnn = models.Sequential()

cnn.add(layers.Input(shape=(64, 64, 3)))
cnn.add(layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(layers.BatchNormalization())
cnn.add(layers.MaxPooling2D(pool_size=(2, 2)))

cnn.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn.add(layers.BatchNormalization())
cnn.add(layers.MaxPooling2D(pool_size=(2, 2)))

cnn.add(layers.Conv2D(filters=128, kernel_size=3, activation='relu'))
cnn.add(layers.BatchNormalization())
cnn.add(layers.MaxPooling2D(pool_size=(2, 2)))

cnn.add(layers.Flatten())
cnn.add(layers.Dense(units=128, activation='relu'))
cnn.add(layers.BatchNormalization())
cnn.add(layers.Dropout(0.5))

cnn.add(layers.Dense(units=64, activation='relu'))
cnn.add(layers.BatchNormalization())
cnn.add(layers.Dropout(0.5))

cnn.add(layers.Dense(units=1, activation='sigmoid'))

cnn.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Training
history = cnn.fit(
    x=training_set,
    validation_data=test_set,
    epochs=150,  # Increased epochs
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/150
# 126/126 [==============================] - ETA: 0s - loss: 0.9755 - accuracy: 0.5463
# Epoch 1: val_accuracy improved from -inf to 0.45092, saving model to best_model.keras
# 126/126 [==============================] - 139s 998ms/step - loss: 0.9755 - accuracy: 0.5463 - val_loss: 0.8343 - val_accuracy: 0.4509
# Epoch 2/150
# 126/126 [==============================] - ETA: 0s - loss: 0.8837 - accuracy: 0.5779
# Epoch 2: val_accuracy did not improve from 0.45092
# 126/126 [==============================] - 174s 1s/step - loss: 0.8837 - accuracy: 0.5779 - val_loss: 1.0507 - val_accuracy: 0.4499
# Epoch 3/150
# 126/126 [==============================] - ETA: 0s - loss: 0.8640 - accuracy: 0.5822
# Epoch 3: val_accuracy improved from 0.45092 to 0.52556, saving model to best_model.keras
# 126/126 [==============================] - 127s 1s/step - loss: 0.8640 - accuracy: 0.5822 - val_loss: 0.7616 - val_accuracy: 0.5256
# Epoch 4/150
# 126/126 [==============================] - ETA: 0s - loss: 0.8149 - accuracy: 0.6074
# Epoch 4: val_accuracy improved from 0.52556 to 0.62372, saving model to best_model.keras
# 126/126 [==============================] - 97s 765ms/step - loss: 0.8149 - accuracy: 0.6074 - val_loss: 0.6604 - val_accuracy: 0.6237
# Epoch 5/150
# 126/126 [==============================] - ETA: 0s - loss: 0.8041 - accuracy: 0.6134
# Epoch 5: val_accuracy improved from 0.62372 to 0.66973, saving model to best_model.keras
# 126/126 [==============================] - 104s 818ms/step - loss: 0.8041 - accuracy: 0.6134 - val_loss: 0.6291 - val_accuracy: 0.6697
# Epoch 6/150
# 126/126 [==============================] - ETA: 0s - loss: 0.7949 - accuracy: 0.6156
# Epoch 6: val_accuracy improved from 0.66973 to 0.67587, saving model to best_model.keras
# 126/126 [==============================] - 82s 636ms/step - loss: 0.7949 - accuracy: 0.6156 - val_loss: 0.6891 - val_accuracy: 0.6759
# Epoch 7/150
# 126/126 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.6333
# Epoch 7: val_accuracy did not improve from 0.67587
# 126/126 [==============================] - 96s 766ms/step - loss: 0.7444 - accuracy: 0.6333 - val_loss: 0.6431 - val_accuracy: 0.6728
# Epoch 8/150
# 126/126 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.6351
# Epoch 8: val_accuracy did not improve from 0.67587
# 126/126 [==============================] - 97s 767ms/step - loss: 0.7371 - accuracy: 0.6351 - val_loss: 0.6530 - val_accuracy: 0.6759
# Epoch 9/150
# 126/126 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.6423
# Epoch 9: val_accuracy improved from 0.67587 to 0.69836, saving model to best_model.keras
# 126/126 [==============================] - 126s 991ms/step - loss: 0.7169 - accuracy: 0.6423 - val_loss: 0.5848 - val_accuracy: 0.6984
# Epoch 10/150
# 126/126 [==============================] - ETA: 0s - loss: 0.7210 - accuracy: 0.6468
# Epoch 10: val_accuracy did not improve from 0.69836
# 126/126 [==============================] - 111s 855ms/step - loss: 0.7210 - accuracy: 0.6468 - val_loss: 0.6122 - val_accuracy: 0.6738
# Epoch 11/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.6510
# Epoch 11: val_accuracy did not improve from 0.69836
# 126/126 [==============================] - 97s 771ms/step - loss: 0.6929 - accuracy: 0.6510 - val_loss: 0.5874 - val_accuracy: 0.6984
# Epoch 12/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.6623
# Epoch 12: val_accuracy improved from 0.69836 to 0.70245, saving model to best_model.keras
# 126/126 [==============================] - 83s 648ms/step - loss: 0.6897 - accuracy: 0.6623 - val_loss: 0.5835 - val_accuracy: 0.7025
# Epoch 13/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6698 - accuracy: 0.6730
# Epoch 13: val_accuracy improved from 0.70245 to 0.70654, saving model to best_model.keras
# 126/126 [==============================] - 96s 764ms/step - loss: 0.6698 - accuracy: 0.6730 - val_loss: 0.5878 - val_accuracy: 0.7065
# Epoch 14/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6748 - accuracy: 0.6640
# Epoch 14: val_accuracy improved from 0.70654 to 0.71575, saving model to best_model.keras
# 126/126 [==============================] - 84s 637ms/step - loss: 0.6748 - accuracy: 0.6640 - val_loss: 0.5740 - val_accuracy: 0.7157
# Epoch 15/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.6735
# Epoch 15: val_accuracy improved from 0.71575 to 0.71984, saving model to best_model.keras
# 126/126 [==============================] - 75s 592ms/step - loss: 0.6625 - accuracy: 0.6735 - val_loss: 0.5565 - val_accuracy: 0.7198
# Epoch 16/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.6795
# Epoch 16: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 63s 504ms/step - loss: 0.6422 - accuracy: 0.6795 - val_loss: 0.5989 - val_accuracy: 0.6820
# Epoch 17/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6330 - accuracy: 0.6827
# Epoch 17: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 72s 571ms/step - loss: 0.6330 - accuracy: 0.6827 - val_loss: 0.6066 - val_accuracy: 0.6881
# Epoch 18/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.6830
# Epoch 18: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 89s 708ms/step - loss: 0.6400 - accuracy: 0.6830 - val_loss: 0.5540 - val_accuracy: 0.7025
# Epoch 19/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.6922
# Epoch 19: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 75s 599ms/step - loss: 0.6200 - accuracy: 0.6922 - val_loss: 0.5656 - val_accuracy: 0.7178
# Epoch 20/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6205 - accuracy: 0.6957
# Epoch 20: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 126s 998ms/step - loss: 0.6205 - accuracy: 0.6957 - val_loss: 0.5862 - val_accuracy: 0.7014
# Epoch 21/150
# 126/126 [==============================] - ETA: 0s - loss: 0.6141 - accuracy: 0.6912
# Epoch 21: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 119s 943ms/step - loss: 0.6141 - accuracy: 0.6912 - val_loss: 0.5620 - val_accuracy: 0.7137
# Epoch 22/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.7077
# Epoch 22: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 116s 920ms/step - loss: 0.5982 - accuracy: 0.7077 - val_loss: 0.5687 - val_accuracy: 0.7178
# Epoch 23/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5936 - accuracy: 0.6977
# Epoch 23: val_accuracy did not improve from 0.71984
# 126/126 [==============================] - 96s 765ms/step - loss: 0.5936 - accuracy: 0.6977 - val_loss: 0.5610 - val_accuracy: 0.7147
# Epoch 24/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0.6952
# Epoch 24: val_accuracy improved from 0.71984 to 0.72086, saving model to best_model.keras
# 126/126 [==============================] - 96s 764ms/step - loss: 0.5935 - accuracy: 0.6952 - val_loss: 0.5828 - val_accuracy: 0.7209
# Epoch 25/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5865 - accuracy: 0.7067
# Epoch 25: val_accuracy did not improve from 0.72086
# 126/126 [==============================] - 86s 678ms/step - loss: 0.5865 - accuracy: 0.7067 - val_loss: 0.5705 - val_accuracy: 0.7168
# Epoch 26/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.7189
# Epoch 26: val_accuracy did not improve from 0.72086
# 126/126 [==============================] - 119s 950ms/step - loss: 0.5616 - accuracy: 0.7189 - val_loss: 0.5492 - val_accuracy: 0.7086
# Epoch 27/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.7146
# Epoch 27: val_accuracy did not improve from 0.72086
# 126/126 [==============================] - 118s 933ms/step - loss: 0.5809 - accuracy: 0.7146 - val_loss: 0.5479 - val_accuracy: 0.7137
# Epoch 28/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.7229
# Epoch 28: val_accuracy improved from 0.72086 to 0.73006, saving model to best_model.keras
# 126/126 [==============================] - 108s 862ms/step - loss: 0.5671 - accuracy: 0.7229 - val_loss: 0.5291 - val_accuracy: 0.7301
# Epoch 29/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5428 - accuracy: 0.7279
# Epoch 29: val_accuracy did not improve from 0.73006
# 126/126 [==============================] - 98s 760ms/step - loss: 0.5428 - accuracy: 0.7279 - val_loss: 0.5377 - val_accuracy: 0.7209
# Epoch 30/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.7311
# Epoch 30: val_accuracy improved from 0.73006 to 0.73722, saving model to best_model.keras
# 126/126 [==============================] - 81s 640ms/step - loss: 0.5475 - accuracy: 0.7311 - val_loss: 0.5176 - val_accuracy: 0.7372
# Epoch 31/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.7368
# Epoch 31: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 105s 838ms/step - loss: 0.5386 - accuracy: 0.7368 - val_loss: 0.5271 - val_accuracy: 0.7352
# Epoch 32/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5455 - accuracy: 0.7356
# Epoch 32: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 67s 503ms/step - loss: 0.5455 - accuracy: 0.7356 - val_loss: 0.5515 - val_accuracy: 0.7157
# Epoch 33/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5320 - accuracy: 0.7348
# Epoch 33: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 76s 600ms/step - loss: 0.5320 - accuracy: 0.7348 - val_loss: 0.5447 - val_accuracy: 0.7188
# Epoch 34/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5368 - accuracy: 0.7408
# Epoch 34: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 78s 619ms/step - loss: 0.5368 - accuracy: 0.7408 - val_loss: 0.5312 - val_accuracy: 0.7168
# Epoch 35/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.7371
# Epoch 35: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 78s 620ms/step - loss: 0.5357 - accuracy: 0.7371 - val_loss: 0.5261 - val_accuracy: 0.7229
# Epoch 36/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5178 - accuracy: 0.7468
# Epoch 36: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 72s 571ms/step - loss: 0.5178 - accuracy: 0.7468 - val_loss: 0.5103 - val_accuracy: 0.7321
# Epoch 37/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.7436
# Epoch 37: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 93s 745ms/step - loss: 0.5285 - accuracy: 0.7436 - val_loss: 0.5244 - val_accuracy: 0.7362
# Epoch 38/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5172 - accuracy: 0.7518
# Epoch 38: val_accuracy did not improve from 0.73722
# 126/126 [==============================] - 82s 656ms/step - loss: 0.5172 - accuracy: 0.7518 - val_loss: 0.5024 - val_accuracy: 0.7362
# Epoch 39/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5078 - accuracy: 0.7521
# Epoch 39: val_accuracy improved from 0.73722 to 0.74540, saving model to best_model.keras
# 126/126 [==============================] - 65s 516ms/step - loss: 0.5078 - accuracy: 0.7521 - val_loss: 0.5104 - val_accuracy: 0.7454
# Epoch 40/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.7558
# Epoch 40: val_accuracy did not improve from 0.74540
# 126/126 [==============================] - 76s 606ms/step - loss: 0.4986 - accuracy: 0.7558 - val_loss: 0.5214 - val_accuracy: 0.7260
# Epoch 41/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5051 - accuracy: 0.7538
# Epoch 41: val_accuracy improved from 0.74540 to 0.75051, saving model to best_model.keras
# 126/126 [==============================] - 68s 540ms/step - loss: 0.5051 - accuracy: 0.7538 - val_loss: 0.5411 - val_accuracy: 0.7505
# Epoch 42/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5124 - accuracy: 0.7513
# Epoch 42: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 95s 750ms/step - loss: 0.5124 - accuracy: 0.7513 - val_loss: 0.5009 - val_accuracy: 0.7474
# Epoch 43/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4969 - accuracy: 0.7560
# Epoch 43: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 81s 645ms/step - loss: 0.4969 - accuracy: 0.7560 - val_loss: 0.5294 - val_accuracy: 0.7198
# Epoch 44/150
# 126/126 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.7615
# Epoch 44: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 66s 525ms/step - loss: 0.5038 - accuracy: 0.7615 - val_loss: 0.5182 - val_accuracy: 0.7362
# Epoch 45/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.7680
# Epoch 45: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 65s 518ms/step - loss: 0.4828 - accuracy: 0.7680 - val_loss: 0.5024 - val_accuracy: 0.7393
# Epoch 46/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7728
# Epoch 46: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 75s 598ms/step - loss: 0.4928 - accuracy: 0.7728 - val_loss: 0.5048 - val_accuracy: 0.7372
# Epoch 47/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.7670
# Epoch 47: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 75s 594ms/step - loss: 0.4802 - accuracy: 0.7670 - val_loss: 0.4915 - val_accuracy: 0.7454
# Epoch 48/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.7740
# Epoch 48: val_accuracy did not improve from 0.75051
# 126/126 [==============================] - 89s 710ms/step - loss: 0.4808 - accuracy: 0.7740 - val_loss: 0.5000 - val_accuracy: 0.7423
# Epoch 49/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.7755
# Epoch 49: val_accuracy improved from 0.75051 to 0.75665, saving model to best_model.keras
# 126/126 [==============================] - 64s 510ms/step - loss: 0.4653 - accuracy: 0.7755 - val_loss: 0.4789 - val_accuracy: 0.7566
# Epoch 50/150
# 126/126 [==============================] - ETA: 0s - loss: 0.4896 - accuracy: 0.7628
# Epoch 50: val_accuracy did not improve from 0.75665
# 126/126 [==============================] - 63s 503ms/step - loss: 0.4896 - accuracy: 0.7628 - val_loss: 0.4894 - val_accuracy: 0.7566
# Epoch 51/150
# 126/126 [==============================] - ETA: 0s - loss: 0.
150
# 126/126 [==============================] - ETA: 0s - loss: 0.3214 - accuracy: 0.8641
# Epoch 116: val_accuracy did not improve from 0.82004
# 126/126 [==============================] - 93s 740ms/step - loss: 0.3214 - accuracy: 0.8641 - val_loss: 0.4309 - val_accuracy: 0.8119
# Epoch 117/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8586
# Epoch 117: val_accuracy did not improve from 0.82004
# 126/126 [==============================] - 68s 541ms/step - loss: 0.3205 - accuracy: 0.8586 - val_loss: 0.4200 - val_accuracy: 0.8119
# Epoch 118/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8616
# Epoch 118: val_accuracy improved from 0.82004 to 0.82311, saving model to best_model.keras
# 126/126 [==============================] - 64s 507ms/step - loss: 0.3211 - accuracy: 0.8616 - val_loss: 0.4112 - val_accuracy: 0.8231
# Epoch 119/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8598
# Epoch 119: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 63s 506ms/step - loss: 0.3189 - accuracy: 0.8598 - val_loss: 0.4729 - val_accuracy: 0.7863
# Epoch 120/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.8636
# Epoch 120: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 65s 514ms/step - loss: 0.3088 - accuracy: 0.8636 - val_loss: 0.4349 - val_accuracy: 0.8037
# Epoch 121/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8646
# Epoch 121: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 67s 531ms/step - loss: 0.3196 - accuracy: 0.8646 - val_loss: 0.4003 - val_accuracy: 0.8180
# Epoch 122/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.8593
# Epoch 122: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 71s 561ms/step - loss: 0.3245 - accuracy: 0.8593 - val_loss: 0.4124 - val_accuracy: 0.8149
# Epoch 123/150
# 126/126 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8705
# Epoch 123: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 63s 504ms/step - loss: 0.2946 - accuracy: 0.8705 - val_loss: 0.4080 - val_accuracy: 0.8160
# Epoch 124/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.8718
# Epoch 124: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 63s 499ms/step - loss: 0.3065 - accuracy: 0.8718 - val_loss: 0.4441 - val_accuracy: 0.8067
# Epoch 125/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8648
# Epoch 125: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 65s 515ms/step - loss: 0.3059 - accuracy: 0.8648 - val_loss: 0.4235 - val_accuracy: 0.8027
# Epoch 126/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8700
# Epoch 126: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 63s 506ms/step - loss: 0.3001 - accuracy: 0.8700 - val_loss: 0.4269 - val_accuracy: 0.7924
# Epoch 127/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.8680
# Epoch 127: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 68s 543ms/step - loss: 0.3022 - accuracy: 0.8680 - val_loss: 0.4546 - val_accuracy: 0.7873
# Epoch 128/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8606
# Epoch 128: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 88s 696ms/step - loss: 0.3074 - accuracy: 0.8606 - val_loss: 0.4177 - val_accuracy: 0.8088
# Epoch 129/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.8688
# Epoch 129: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 65s 516ms/step - loss: 0.3014 - accuracy: 0.8688 - val_loss: 0.4268 - val_accuracy: 0.8149
# Epoch 130/150
# 126/126 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8718
# Epoch 130: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 85s 674ms/step - loss: 0.2944 - accuracy: 0.8718 - val_loss: 0.4607 - val_accuracy: 0.7843
# Epoch 131/150
# 126/126 [==============================] - ETA: 0s - loss: 0.3084 - accuracy: 0.8596
# Epoch 131: val_accuracy did not improve from 0.82311
# 126/126 [==============================] - 67s 532ms/step - loss: 0.3084 - accuracy: 0.8596 - val_loss: 0.4474 - val_accuracy: 0.8016

# %%
import tensorflow as tf

# Load the best model for conversion
best_model = models.load_model('best_model.keras')

# Convert to TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Model converted to TensorFlow Lite and saved as 'model.tflite'.")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpfvbn80oz/assets
# INFO:tensorflow:Assets written to: /tmp/tmpfvbn80oz/assets
# Model converted to TensorFlow Lite and saved as 'model.tflite'.
# 2024-10-15 17:53:00.701381: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2024-10-15 17:53:00.701404: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2024-10-15 17:53:00.701508: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /tmp/tmpfvbn80oz
# 2024-10-15 17:53:00.704209: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2024-10-15 17:53:00.704223: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /tmp/tmpfvbn80oz
# 2024-10-15 17:53:00.715596: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2024-10-15 17:53:00.799118: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /tmp/tmpfvbn80oz
# 2024-10-15 17:53:00.824612: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 123105 microseconds.

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper left')
plt.show()

# %%
# Assuming 'history' is the object returned from model.fit()
final_training_accuracy = history.history['accuracy'][-1]  # Last training accuracy
final_validation_accuracy = history.history['val_accuracy'][-1]  # Last validation accuracy

print(f"Final Training Accuracy: {final_training_accuracy:.4f}")
print(f"Final Validation Accuracy: {final_validation_accuracy:.4f}")
# Out:
# Final Training Accuracy: 0.8596
# Final Validation Accuracy: 0.8016

# %%
# !pip install opencv-python
import cv2
print(cv2.__version__)
# Out:
# Requirement already satisfied: opencv-python in /home/saicharan/.local/lib/python3.8/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.3; python_version >= "3.8" in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.24.3)
# 4.10.0

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2  # OpenCV for face detection
import tensorflow as tf

# Load the TensorFlow Lite model and allocate tensors
interpreter = tf.lite.Interpreter(model_path='model.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def detect_faces(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    return faces

def predict_gender_population(img_path):
    print(f'Processing image: {img_path}')
    if not os.path.isfile(img_path):
        print(f"Error: File not found - {img_path}")
        return

    original_img = cv2.imread(img_path)

    faces = detect_faces(original_img)
    total_count = len(faces)
    print(f'Total number of people detected: {total_count}')

    gender_results = []

    for (x, y, w, h) in faces:
        face = original_img[y:y+h, x:x+w]
        face_resized = cv2.resize(face, (64, 64))
        face_resized_array = face_resized / 255.0
        face_resized_array = np.expand_dims(face_resized_array, axis=0).astype(np.float32)  # Convert to FLOAT32

        # Use the TFLite model for prediction
        interpreter.set_tensor(input_details[0]['index'], face_resized_array)
        interpreter.invoke()
        prediction = interpreter.get_tensor(output_details[0]['index'])

        # Print the raw prediction value for debugging
        print(f'Raw prediction for face at ({x}, {y}): {prediction[0][0]}')

        # Adjust the threshold if necessary
        if prediction[0][0] > 0.5:
            gender = 'Female'
        else:
            gender = 'Male'

        gender_results.append(gender)

        cv2.rectangle(original_img, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv2.putText(original_img, gender, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)

    plt.imshow(cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(f'Total People Detected: {total_count}')
    plt.show()

    for i, gender in enumerate(gender_results):
        print(f'Person {i+1}: Predicted Gender: {gender}')

# Example usage
predict_gender_population('Pop12.jpeg')
# Out:
# Processing image: Pop12.jpeg
# Total number of people detected: 2
# Raw prediction for face at (66, 39): 0.25313761830329895
# Raw prediction for face at (135, 30): 0.014164892956614494
# Person 1: Predicted Gender: Male
# Person 2: Predicted Gender: Male
